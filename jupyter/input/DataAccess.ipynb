# %% [markdown]
# # OMA Data Access
#
# Example: fetching list of composers
#
# composers = oma.composer_list(params)

# %% [markdown]
# ## Parameters for list methods
#
#     max - The maximum number to list
#     offset - The offset from the first result to list from
#     order - How to order the list, either "desc" or "asc"
#     sort - The property name to sort by
#     ignoreCase - Whether to ignore the case when sorting. Default is true.
#     fetch - The fetch policy for the object's associations as a Map
#     readOnly - true if returned objects should not be automatically dirty-checked (simlar to read())
#     fetchSize - number of rows fetched by the underlying JDBC driver per round trip
#     flushMode - Hibernate FlushMode override, defaults to FlushMode.AUTO
#     timeout - query timeout in seconds

# %%
from omapy.api import oma
import pandas as pd

# API endpoint
url = "http://localhost:8080/"
# Login with username, password and flag that indicates if certificates are validated or not. False: useful for non-production
login = oma.login(url, "oma", "=PSe?sZ-ymp6mE>2", False)
# response code 200
print(login)
# Out:
# <Response [200]>

# %%
# list composers
params = {"sort": "name"}
composers = oma.composer_list(params)
df_composers = pd.DataFrame(data=composers)

df_composers.head()
# Out:
#                                         compositions     id  \
# 0  [{'composer': {'class': 'org.karajanresearch.o...   5143
# 1  [{'composer': {'class': 'org.karajanresearch.o...  52790
# 2  [{'composer': {'class': 'org.karajanresearch.o...  29329
# 3  [{'composer': {'class': 'org.karajanresearch.o...      5
#
#                    name  tenantId
# 0        Anton Bruckner         3
# 1          Anton Webern         3
# 2  Ludwig van Beethoven         3
# 3       Richard Strauss         3

# %%
# filter data frame locally
bruckner = df_composers[df_composers.name.eq("Anton Bruckner")]
print(bruckner.id[0])
# Out:
# 5143

# %%
# list compositions
params = {}
compositions = oma.composition_list(params)
df_compositions = pd.DataFrame(data=compositions)
df_compositions.head()
# Out:
#         composer     id  tenantId             title
# 0      {'id': 5}      6         3   Don Juan Op. 20
# 1   {'id': 5143}   5144         3   Symphonie No. 9
# 2  {'id': 29329}  29330         3   Symphonie No. 9
# 3  {'id': 52790}  52791         3  Symphonie Op. 21

# %%
bruckner_sym9 = df_compositions[df_compositions.composer.eq({"id": bruckner.id[0]})]
bruckner_sym9
# Out:
#        composer    id  tenantId            title
# 1  {'id': 5143}  5144         3  Symphonie No. 9

# %%
# find interpretations
params = {"findBy": "composition", "composition": bruckner_sym9.id}
interpretations = oma.interpretation_find(params)

df_interpretations = pd.DataFrame(data=interpretations)

df_interpretations.head()
# Out:
#                                        abstractMusic  abstractMusicId  \
# 0  {'composer': {'id': 5143}, 'id': 5144, 'tenant...             5144
# 1  {'composer': {'id': 5143}, 'id': 5144, 'tenant...             5144
# 2  {'composer': {'id': 5143}, 'id': 5144, 'tenant...             5144
# 3  {'composer': {'id': 5143}, 'id': 5144, 'tenant...             5144
# 4  {'composer': {'id': 5143}, 'id': 5144, 'tenant...             5144
#
#    barNumberOffset                compositionString  \
# 0            150.0  Anton Bruckner: Symphonie No. 9
# 1            150.0  Anton Bruckner: Symphonie No. 9
# 2            150.0  Anton Bruckner: Symphonie No. 9
# 3            150.0  Anton Bruckner: Symphonie No. 9
# 4            150.0  Anton Bruckner: Symphonie No. 9
#
#                                       interpretation  interpretationId  \
# 0  {'abstractMusicParts': [{'id': 5146}], 'id': 5...              5145
# 1  {'abstractMusicParts': [{'id': 7422}], 'id': 7...              7421
# 2  {'abstractMusicParts': [{'id': 8574}], 'id': 8...              8573
# 3  {'abstractMusicParts': [{'id': 9330}], 'id': 9...              9329
# 4  {'abstractMusicParts': [{'id': 5910}], 'id': 5...              5909
#
#    interpretationOrder                               interpretationString  \
# 0                    3        Eugen Jochum, Berliner Philharmoniker, 1966
# 1                    3                Abbado, Wiener Philharmoniker, 1996
# 2                    3   Carlo Maria Giulini, Wiener Philharmoniker, 1988
# 3                    3     Leonard Bernstein, Wiener Philharmoniker, 1990
# 4                    3  Herbert von Karajan, Berliner Philharmoniker, ...
#
#    numberOfBars                                        pdfLocation  \
# 0          93.0  https://s3.amazonaws.com/open-music-annotation...
# 1          93.0  https://s3.amazonaws.com/open-music-annotation...
# 2          93.0  https://s3.amazonaws.com/open-music-annotation...
# 3          93.0  https://s3.amazonaws.com/open-music-annotation...
# 4          93.0  https://s3.amazonaws.com/open-music-annotation...
#
#   pdfPageChangeAnnotationSession pdfPageChangeAnnotationSessionId  tenantId  \
# 0                           None                             None         3
# 1                           None                             None         3
# 2                           None                             None         3
# 3                           None                             None         3
# 4                           None                             None         3
#
#         title
# 0  Movement 3
# 1  Movement 3
# 2  Movement 3
# 3  Movement 3
# 4  Movement 3

# %%
# recordings
a_recording_id = df_interpretations["interpretation"][0]["recordings"][0]["id"]
print(a_recording_id)
# Out:
# 24399
