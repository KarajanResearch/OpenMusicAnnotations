# %% [markdown]
# # Bootstrapping Composers from Wikipedia

# %%
import requests
import json

url = "https://en.wikipedia.org/wiki/List_of_composers_by_name"
r = requests.get(url, allow_redirects=True)


try: 
    from BeautifulSoup import BeautifulSoup
except ImportError:
    from bs4 import BeautifulSoup
    
html = r.content

parsed_html = BeautifulSoup(html)

#print(parsed_html.body.find_all('li'))

tags = parsed_html.body.find_all("li")

composerList = []

for tag in tags:
    a = tag.find("a")
    if a:
        href = a.get("href")
        if href.startswith("/wiki/"):
            #print(a.string)
            try:
                composerName = a.string
                stringParts = str(tag).split("(")
                stringParts = stringParts[1].split(")")
                livedAt = stringParts[0]
                composerList.append({"name": composerName, "livedAt": livedAt})
            except:
                #print("ignoring", a)
                continue
                
print(composerList)
# Out:
# [{'livedAt': '1817–1863', 'name': 'Mary Anne à Beckett'}, {'livedAt': 'born 1970', 'name': 'Michel van der Aa'}, {'livedAt': '1877–1937', 'name': 'Thorvald Aagaard'}, {'livedAt': 'fl. 1593–1625', 'name': 'Truid Aagesen'}, {'livedAt': '1905–1992', 'name': 'Heikki Aaltoila'}, {'livedAt': '1884–1982', 'name': 'Juhan Aavik'}, {'livedAt': '1675–1742', 'name': "Evaristo Felice Dall'Abaco"}, {'livedAt': "dall'Abaco", 'name': 'Joseph Abaco'}, {'livedAt': 'c. 1595–1680', 'name': 'Antonio Maria Abbatini'}, {'livedAt': '1924–1988', 'name': 'Gamal Abdel-Rahim'}, {'livedAt': 'born 1962', 'name': 'Mohamed Abdelwahab Abdelfattah'}, {'livedAt': 'born 1937', 'name': 'Keiko Abe'}, {'livedAt': '1922–1991', 'name': 'Rosalina Abejo'}, {'livedAt': '1723–1787', 'name': 'Carl Friedrich Abel'}, {'livedAt': '1634–1696', 'name': 'Clamor Heinrich Abel'}, {'livedAt': '1835–1895', 'name': 'Ludwig Abel'}, {'livedAt': 'born 1948', 'name': 'Mark Abel'}, {'livedAt': 'born 1962', 'name': 'Michael Abels'}, {'livedAt': '1079–1142', 'name': 'Peter Abelard'}, {'livedAt': '1893–1934', 'name': 'Nicanor Abelardo'}, {'livedAt': 'composer', 'name': 'David Abell'}, {'livedAt': '1653–after 1724', 'name': 'John Abell'}, {'livedAt': '1896–1973', 'name': 'Walter Abendroth'}, {'livedAt': 'born 1916', 'name': 'Jan Håkan Åberg'}, {'livedAt': 'born 1940', 'name': 'Lasse Åberg'}, {'livedAt': '1832–1915', 'name': 'Johann Joseph Abert'}, {'livedAt': 'Willoughby Bertie', 'name': '4th Earl of Abingdon'}, {'livedAt': 'born 1959', 'name': 'Peter Ablinger'}, {'livedAt': '1907–2005', 'name': 'Lora Aborn'}, {'livedAt': '1715–1760', 'name': 'Girolamo Abos'}, {'livedAt': '1892–1960', 'name': 'Paul Abraham'}, {