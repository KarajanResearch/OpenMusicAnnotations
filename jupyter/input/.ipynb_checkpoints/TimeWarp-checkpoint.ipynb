# %% [markdown]
# # Time warp

# %%
# Login
from omapy.api import oma

# API endpoint
url = "http://localhost:8080/"
# url = "http://omatest.eu-central-1.elasticbeanstalk.com/"
# Login with username, password and flag that indicates if certificates are validated or not. False: useful for non-production
login = oma.login(url, "oma", "=PSe?sZ-ymp6mE>2", False)
# response code 200
print(login)
# Out:
# <Response [200]>

# %%
recordingId1 = 35476
recordingId2 = 34669


params = {"recording": recordingId1, "type": "wav"}
audio_file1 = oma.recording_get_audio(params)
print(audio_file1.name)

params = {"recording": recordingId2, "type": "wav"}
audio_file2 = oma.recording_get_audio(params)
print(audio_file2.name)
# Out:
# opened
# omacache/recording/35476.wav
# opened
# omacache/recording/34669.wav

# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt

y, sr = librosa.load(audio_file1.name)
X = librosa.feature.chroma_cens(y=y, sr=sr)

y, sr = librosa.load(audio_file2.name)
Y = librosa.feature.chroma_cens(y=y, sr=sr)

D, wp = librosa.sequence.dtw(X, Y, subseq=True)

plt.subplot(2, 1, 1)
librosa.display.specshow(D, x_axis='frames', y_axis='frames')

plt.show()

# %%
plt.subplot(2, 1, 1)
librosa.display.specshow(D, x_axis='frames', y_axis='frames')
plt.title('Track alignment')
plt.plot(wp[:, 1], wp[:, 0], label='Optimal path', color='y')
plt.legend()
plt.subplot(2, 1, 2)
plt.plot(D[-1, :] / wp.shape[0])
plt.xlim([0, Y.shape[1]])
plt.ylim([0, 2])
plt.title('Matching cost function')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result, async_)
#    3325                 else:
# -> 3326                     exec(code_obj, self.user_global_ns, self.user_ns)
#    3327             finally:
#
# <ipython-input-11-35c08001945d> in <module>
#      10 plt.title('Matching cost function')
# ---> 11 plt.tight_layout()
#      12 plt.show()
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/pyplot.py in tight_layout(pad, h_pad, w_pad, rect)
#    1381     """
# -> 1382     gcf().tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    1383
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    2376             self, self.axes, subplotspec_list, renderer,
# -> 2377             pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    2378         if kwargs:
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/tight_layout.py in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     365                                      ax_bbox_list=ax_bbox_list,
# --> 366                                      pad=pad, h_pad=h_pad, w_pad=w_pad)
#     367
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/tight_layout.py in auto_adjust_subplotpars(fig, renderer, nrows_ncols, num1num2_list, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#     114
# --> 115         tight_bbox_raw = union([ax.get_tightbbox(renderer) for ax in subplots
#     116                                 if ax.get_visible()])
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/tight_layout.py in <listcomp>(.0)
#     115         tight_bbox_raw = union([ax.get_tightbbox(renderer) for ax in subplots
# --> 116                                 if ax.get_visible()])
#     117         tight_bbox = TransformedBbox(tight_bbox_raw,
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4395         for a in bbox_artists:
# -> 4396             bbox = a.get_tightbbox(renderer)
#    4397             if (bbox is not None and
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/legend.py in get_tightbbox(self, renderer)
#    1003         """
# -> 1004         return self._legend_box.get_window_extent(renderer)
#    1005
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/offsetbox.py in get_window_extent(self, renderer)
#     250         w, h, xd, yd, offsets = self.get_extent_offsets(renderer)
# --> 251         px, py = self.get_offset(w, h, xd, yd, renderer)
#     252         return mtransforms.Bbox.from_bounds(px - xd, py - yd, w, h)
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/offsetbox.py in get_offset(self, width, height, xdescent, ydescent, renderer)
#     202         return (self._offset(width, height, xdescent, ydescent, renderer)
# --> 203                 if callable(self._offset)
#     204                 else self._offset)
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/legend.py in _findoffset(self, width, height, xdescent, ydescent, renderer)
#     604         if self._loc == 0:  # "best".
# --> 605             x, y = self._find_best_position(width, height, renderer)
#     606         elif self._loc in Legend.codes.values():  # Fixed location.
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/legend.py in _find_best_position(self, width, height, renderer, consider)
#    1107
# -> 1108         verts, bboxes, lines, offsets = self._auto_legend_data()
#    1109
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/legend.py in _auto_legend_data(self)
#     907         for handle in ax.collections:
# --> 908             transform, transOffset, hoffsets, paths = handle._prepare_points()
#     909
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/collections.py in _prepare_points(self)
#     221         offsets = self._offsets
# --> 222         paths = self.get_paths()
#     223
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/collections.py in get_paths(self)
#    1827         if self._paths is None:
# -> 1828             self.set_paths()
#    1829         return self._paths
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/collections.py in set_paths(self)
#    1832         self._paths = self.convert_mesh_to_paths(
# -> 1833             self._meshWidth, self._meshHeight, self._coordinates)
#    1834         self.stale = True
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/collections.py in convert_mesh_to_paths(meshWidth, meshHeight, coordinates)
#    1859         points = points.reshape((meshWidth * meshHeight, 5, 2))
# -> 1860         return [mpath.Path(x) for x in points]
#    1861
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/collections.py in <listcomp>(.0)
#    1859         points = points.reshape((meshWidth * meshHeight, 5, 2))
# -> 1860         return [mpath.Path(x) for x in points]
#    1861
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     148         self._interpolation_steps = _interpolation_steps
# --> 149         self._update_values()
#     150
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/path.py in _update_values(self)
#     200         )
# --> 201         self._has_nonfinite = not np.isfinite(self._vertices).all()
#     202
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/numpy/core/_methods.py in _all(a, axis, dtype, out, keepdims)
#      47 def _all(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 48     return umr_all(a, axis, dtype, out, keepdims)
#      49
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7fd7a8cebbf8> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     130         for f_mgr in cls.get_all_fig_managers():
#     131             if force or f_mgr.canvas.figure.stale:
# --> 132                 f_mgr.canvas.draw_idle()
#     133
#     134 atexit.register(Gcf.destroy_all)
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1897         if not self._is_idle_drawing:
#    1898             with self._idle_draw_cntx():
# -> 1899                 self.draw(*args, **kwargs)
#    1900
#    1901     def draw_cursor(self, event):
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/Workspace/oma/jupyter/JUPYTER/lib/python3.5/site-packages/matplotlib/collections.py in draw(self, renderer)
#    1944                 gc, transform.frozen(), self._meshWidth, self._meshHeight,
#    1945                 coordinates, offsets, transOffset, self.get_facecolor(),
# -> 1946                 self._antialiased, self.get_edgecolors())
#    1947         gc.restore()
#    1948         renderer.close_group(self.__class__.__name__)
#
# KeyboardInterrupt:

# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt

y, sr = librosa.load(audio_file1.name)
X = librosa.feature.chroma_cens(y=y, sr=sr)

y, sr = librosa.load(audio_file2.name)
Y = librosa.feature.chroma_cens(y=y, sr=sr)

D, wp = librosa.sequence.dtw(X, Y, subseq=True)

plt.subplot(2, 1, 1)
librosa.display.specshow(D, x_axis='frames', y_axis='frames')

plt.show()
